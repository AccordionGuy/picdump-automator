# %%
import base64
import mimetypes
import os
from datetime import datetime, timedelta
from pathlib import Path
from typing import Dict, List, Optional

import requests
from dotenv import load_dotenv


class WordPressUploader:
    def __init__(self, site_url: str, username: str, password: str):
        """
        Initialize WordPress uploader with site credentials.
        
        Args:
            site_url: WordPress site URL (e.g., 'https://yoursite.com')
            username: WordPress username
            password: WordPress application password (not regular password)
        """
        self.site_url = site_url.rstrip('/')
        self.username = username
        self.password = password
        self.api_base = f"{self.site_url}/wp-json/wp/v2"
        
        # Create authentication header
        credentials = f"{username}:{password}"
        token = base64.b64encode(credentials.encode()).decode()
        self.headers = {
            'Authorization': f'Basic {token}',
            'Content-Type': 'application/json'
        }
    
    def test_connection(self) -> bool:
        """Test if we can connect to WordPress API."""
        try:
            response = requests.get(f"{self.api_base}/users/me", headers=self.headers)
            if response.status_code == 200:
                print("✅ Successfully connected to WordPress!")
                return True
            else:
                print(f"❌ Connection failed: {response.status_code} - {response.text}")
                return False
        except Exception as e:
            print(f"❌ Connection error: {str(e)}")
            return False
    
    def upload_image(self, image_path: str) -> Optional[Dict]:
        """
        Upload a single image to WordPress media library.
        
        Args:
            image_path: Path to the image file
            
        Returns:
            Dictionary with image info if successful, None if failed
        """
        if not os.path.exists(image_path):
            print(f"❌ Image not found: {image_path}")
            return None
        
        # Get file info
        filename = os.path.basename(image_path)
        mime_type, _ = mimetypes.guess_type(image_path)
        
        if not mime_type or not mime_type.startswith('image/'):
            print(f"❌ Not a valid image file: {filename}")
            return None
        
        try:
            # Read image file
            with open(image_path, 'rb') as f:
                image_data = f.read()
            
            # Prepare headers for media upload
            upload_headers = {
                'Authorization': self.headers['Authorization'],
                'Content-Type': mime_type,
                'Content-Disposition': f'attachment; filename="{filename}"'
            }
            
            # Upload to WordPress
            response = requests.post(
                f"{self.api_base}/media",
                headers=upload_headers,
                data=image_data
            )
            
            if response.status_code == 201:
                media_info = response.json()
                print(f"✅ Uploaded: {filename} (ID: {media_info['id']})")
                return media_info
            else:
                print(f"❌ Failed to upload {filename}: {response.status_code} - {response.text}")
                return None
                
        except Exception as e:
            print(f"❌ Error uploading {filename}: {str(e)}")
            return None
    
    def upload_images_from_folder(self, folder_path: str, extensions: List[str] = None) -> List[Dict]:
        """
        Upload all images from a folder.
        
        Args:
            folder_path: Path to folder containing images
            extensions: List of file extensions to include (default: common image formats)
            
        Returns:
            List of uploaded image info dictionaries
        """
        if extensions is None:
            extensions = ['.jpg', '.jpeg', '.png', '.gif', '.bmp', '.webp']
        
        if not os.path.exists(folder_path):
            print(f"❌ Folder not found: {folder_path}")
            return []
        
        uploaded_images = []
        folder = Path(folder_path)
        
        # Find all image files
        image_files = []
        for ext in extensions:
            image_files.extend(folder.glob(f"*{ext}"))
            image_files.extend(folder.glob(f"*{ext.upper()}"))
        
        if not image_files:
            print(f"❌ No image files found in {folder_path}")
            return []
        
        print(f"📁 Found {len(image_files)} image(s) in folder")
        
        # Upload each image
        for image_file in sorted(image_files):
            media_info = self.upload_image(str(image_file))
            if media_info:
                uploaded_images.append(media_info)
        
        print(f"✅ Successfully uploaded {len(uploaded_images)} out of {len(image_files)} images")
        return uploaded_images
    
    def get_or_create_category(self, category_name: str) -> Optional[int]:
        """
        Get category ID by name, or create it if it doesn't exist.
        
        Args:
            category_name: Name of the category
            
        Returns:
            Category ID if successful, None if failed
        """
        try:
            # First, try to find existing category
            response = requests.get(
                f"{self.api_base}/categories",
                headers=self.headers,
                params={'search': category_name}
            )
            
            if response.status_code == 200:
                categories = response.json()
                # Look for exact match
                for cat in categories:
                    if cat['name'].lower() == category_name.lower():
                        print(f"📂 Found existing category: {category_name} (ID: {cat['id']})")
                        return cat['id']
            
            # Category doesn't exist, create it
            create_response = requests.post(
                f"{self.api_base}/categories",
                headers=self.headers,
                json={'name': category_name}
            )
            
            if create_response.status_code == 201:
                new_cat = create_response.json()
                print(f"📂 Created new category: {category_name} (ID: {new_cat['id']})")
                return new_cat['id']
            else:
                print(f"❌ Failed to create category '{category_name}': {create_response.text}")
                return None
                
        except Exception as e:
            print(f"❌ Error with category '{category_name}': {str(e)}")
            return None
    
    def get_or_create_tag(self, tag_name: str) -> Optional[int]:
        """
        Get tag ID by name, or create it if it doesn't exist.
        
        Args:
            tag_name: Name of the tag
            
        Returns:
            Tag ID if successful, None if failed
        """
        try:
            # First, try to find existing tag
            response = requests.get(
                f"{self.api_base}/tags",
                headers=self.headers,
                params={'search': tag_name}
            )
            
            if response.status_code == 200:
                tags = response.json()
                # Look for exact match
                for tag in tags:
                    if tag['name'].lower() == tag_name.lower():
                        print(f"🏷️  Found existing tag: {tag_name} (ID: {tag['id']})")
                        return tag['id']
            
            # Tag doesn't exist, create it
            create_response = requests.post(
                f"{self.api_base}/tags",
                headers=self.headers,
                json={'name': tag_name}
            )
            
            if create_response.status_code == 201:
                new_tag = create_response.json()
                print(f"🏷️  Created new tag: {tag_name} (ID: {new_tag['id']})")
                return new_tag['id']
            else:
                print(f"❌ Failed to create tag '{tag_name}': {create_response.text}")
                return None
                
        except Exception as e:
            print(f"❌ Error with tag '{tag_name}': {str(e)}")
            return None

    def create_post(self, title: str, content: str = "", status: str = "draft", 
                   featured_image_id: Optional[int] = None, categories: List[str] = None,
                   tags: List[str] = None) -> Optional[Dict]:
        """
        Create a new WordPress post.
        
        Args:
            title: Post title
            content: Post content (HTML)
            status: Post status ('draft', 'publish', 'private')
            featured_image_id: ID of image to use as featured image
            categories: List of category names to assign to the post
            tags: List of tag names to assign to the post
            
        Returns:
            Post info dictionary if successful, None if failed
        """
        post_data = {
            'title': title,
            'content': content,
            'status': status
        }
        
        if featured_image_id:
            post_data['featured_media'] = featured_image_id
        
        # Handle categories
        if categories:
            category_ids = []
            for cat_name in categories:
                cat_id = self.get_or_create_category(cat_name)
                if cat_id:
                    category_ids.append(cat_id)
            if category_ids:
                post_data['categories'] = category_ids
        
        # Handle tags
        if tags:
            tag_ids = []
            for tag_name in tags:
                tag_id = self.get_or_create_tag(tag_name)
                if tag_id:
                    tag_ids.append(tag_id)
            if tag_ids:
                post_data['tags'] = tag_ids
        
        try:
            response = requests.post(
                f"{self.api_base}/posts",
                headers=self.headers,
                json=post_data
            )
            
            if response.status_code == 201:
                post_info = response.json()
                print(f"✅ Created post: '{title}' (ID: {post_info['id']})")
                print(f"📝 Post URL: {post_info['link']}")
                return post_info
            else:
                print(f"❌ Failed to create post: {response.status_code} - {response.text}")
                return None
                
        except Exception as e:
            print(f"❌ Error creating post: {str(e)}")
            return None
    
    def create_post_with_images(self, folder_path: str, post_title: str, 
                               post_intro: str = "", post_status: str = "draft",
                               categories: List[str] = None, tags: List[str] = None) -> Optional[Dict]:
        """
        Complete workflow: upload images from folder and create post with them.
        
        Args:
            folder_path: Path to folder containing images
            post_title: Title for the blog post
            post_intro: Introduction text for the post
            post_status: Post status ('draft', 'publish', 'private')
            categories: List of category names to assign to the post
            tags: List of tag names to assign to the post
            
        Returns:
            Post info dictionary if successful, None if failed
        """
        print(f"🚀 Starting upload process for folder: {folder_path}")
        
        # Upload all images
        uploaded_images = self.upload_images_from_folder(folder_path)
        
        if not uploaded_images:
            print("❌ No images were uploaded, cannot create post")
            return None
        
        # Build post content with images
        content_parts = []
        
        if post_intro:
            content_parts.append(f"<p>{post_intro}</p>")
        
        # Add each image to the post
        for i, image_info in enumerate(uploaded_images):
            img_url = image_info['source_url']
            img_title = image_info['title']['rendered']
            img_caption = image_info.get('caption', {}).get('rendered', '')
            
            # Create image HTML
            img_html = f'<figure class="wp-block-image">'
            img_html += f'<img src="{img_url}" alt="{img_title}" />'
            if img_caption:
                img_html += f'<figcaption>{img_caption}</figcaption>'
            img_html += '</figure>'
            
            content_parts.append(img_html)
        
        full_content = '\n\n<hr />'.join(content_parts)
        
        # Use first image as featured image
        featured_image_id = uploaded_images[0]['id']
        
        # Create the post
        post_info = self.create_post(
            title=post_title,
            content=full_content,
            status=post_status,
            featured_image_id=featured_image_id,
            categories=categories,
            tags=tags
        )
        
        return post_info

# %% [markdown]
# ## Global Nerdy Saturday picdum poster

# %%
def closest_saturday():
    """
    Calculate the date of the closest upcoming Saturday.
    If today is Saturday, return today; otherwise, return the next Saturday.
    """
    today = datetime.now()
    if today.weekday() == 5:
        days_until_saturday = 0
    else:
        days_until_saturday = 5 - today.weekday()  # 5 is Saturday, 0 is Monday
        if days_until_saturday < 0 :
            days_until_saturday += 7
    return today + timedelta(days=days_until_saturday)

def title():
    saturday_text = closest_saturday().strftime("%A, %B %d")
    return f"Saturday picdump for {saturday_text}"


SITE_URL = "https://globalnerdy.com"
load_dotenv()
USERNAME = os.getenv("GLOBAL_NERDY_WORDPRESS_USERNAME")
PASSWORD = os.getenv("GLOBAL_NERDY_WORDPRESS_APP_PASSWORD")  # Use application password, not regular password
PHOTO_FOLDER = "/Users/joey/Documents/Blog/Global Nerdy/picdump GN/"
POST_TITLE = title()
POST_INTRO = "Happy Saturday, everyone! Here on Global Nerdy, Saturday means that it’s time for another “picdump” — the weekly assortment of amusing or interesting pictures, comics, and memes I found over the past week. Share and enjoy!"
POST_STATUS = "draft"  # Change to "publish" to publish immediately

# Categories and Tags
CATEGORIES = ["Picdump"]  # Will be created if they don't exist
TAGS = []  # Will be created if they don't exist

# Create uploader instance
uploader = WordPressUploader(SITE_URL, USERNAME, PASSWORD)

# Test connection
if not uploader.test_connection():
    print("❌ Cannot connect to WordPress. Check your credentials and site URL.")
    raise SystemExit(1)

# Upload photos and create post
post_info = uploader.create_post_with_images(
    folder_path=PHOTO_FOLDER,
    post_title=POST_TITLE,
    post_intro=POST_INTRO,
    post_status=POST_STATUS,
    categories=CATEGORIES,
    tags=TAGS
)

if post_info:
    print(f"\n🎉 Success! Post created with {len(post_info)} images")
    print(f"📝 Edit your post at: {post_info['link']}")
else:
    print("\n❌ Failed to create post")
# Out:
# ✅ Successfully connected to WordPress!
# 🚀 Starting upload process for folder: /Users/joey/Documents/Blog/Global Nerdy/picdump GN/
# 📁 Found 46 image(s) in folder
# ✅ Uploaded: 99 bugs.jpg (ID: 44756)
# ✅ Uploaded: Tell me you have no friends without saying you have no friends.jpg (ID: 44757)
# ✅ Uploaded: blue screen ad.jpg (ID: 44758)
# ✅ Uploaded: built it in 2 days using copilot.jpg (ID: 44759)
# ✅ Uploaded: butlerian juhad.jpg (ID: 44760)
# ✅ Uploaded: cat 5.jpg (ID: 44761)
# ✅ Uploaded: code reviews.jpeg (ID: 44762)
# ✅ Uploaded: compiled with 0 errors.jpg (ID: 44763)
# ✅ Uploaded: crud.jpg (ID: 44764)
# ✅ Uploaded: engagement ring for engineers.jpg (ID: 44765)
# ✅ Uploaded: get an excel job.jpg (ID: 44766)
# ✅ Uploaded: girl invites you.jpg (ID: 44767)
# ✅ Uploaded: here for the money.jpg (ID: 44768)
# ✅ Uploaded: how people are using agentic ai.jpg (ID: 44769)
# ✅ Uploaded: how to tell if a photo is ai generated.jpg (ID: 44770)
# ✅ Uploaded: i fear the man.jpg (ID: 44771)
# ✅ Uploaded: i told you so.jpg (ID: 44772)
# ✅ Uploaded: i wish.jpg (ID: 44773)
# ✅ Uploaded: ideas to solve a bug.jpg (ID: 44774)
# ✅ Uploaded: in the fucking trenches.jpg (ID: 44775)
# ✅ Uploaded: its mango now.jpeg (ID: 44776)
# ✅ Uploaded: johan elisach rainforest purchase.jpg (ID: 44777)
# ✅ Uploaded: json bourne.jpeg (ID: 44778)
# ✅ Uploaded: just be honest in this job interview.jpg (ID: 44779)
# ✅ Uploaded: liquid glass.jpeg (ID: 44780)
# ✅ Uploaded: machine learning without stats and math.jpeg (ID: 44781)
# ✅ Uploaded: mario games.jpg (ID: 44782)
# ✅ Uploaded: me stopping cursor.jpg (ID: 44783)
# ✅ Uploaded: mit pirate certificate.jpg (ID: 44784)
# ✅ Uploaded: necromancers dont read tomes anymore.jpg (ID: 44785)
# ✅ Uploaded: office.jpg (ID: 44786)
# ✅ Uploaded: old projects.jpeg (ID: 44787)
# ✅ Uploaded: open the pod bay doors chatgpt.jpg (ID: 44788)
# ✅ Uploaded: over 30 percent of google code now ai generated.jpg (ID: 44789)
# ✅ Uploaded: palpatine-still-coming-to-work-m.jpg (ID: 44790)
# ✅ Uploaded: programmer forgot something.jpg (ID: 44791)
# ✅ Uploaded: random bug - bonjour bear.jpg (ID: 44792)
# ✅ Uploaded: recognizing ai art.jpg (ID: 44793)
# ✅ Uploaded: remember the metaverse hype.jpg (ID: 44794)
# ✅ Uploaded: this language will kill c - cpp.jpg (ID: 44795)
# ✅ Uploaded: towers of hanoi.png (ID: 44796)
# ✅ Uploaded: vibecoding is the future.jpg (ID: 44797)
# ✅ Uploaded: watching sql injections in honeypot.png (ID: 44798)
# ✅ Uploaded: why is claude a contributor on my repo.jpg (ID: 44799)
# ✅ Uploaded: yo this ai stuff is clutch.jpg (ID: 44800)
# ✅ Uploaded: your vibe coded apps security.jpeg (ID: 44801)
# ✅ Successfully uploaded 46 out of 46 images
# 📂 Created new category: Picdumop (ID: 2178)
# 🏷️  Found existing tag: photos (ID: 509)
# 🏷️  Created new tag: gallery (ID: 2179)
# 🏷️  Created new tag: memories (ID: 2180)
# 🏷️  Created new tag: 2025 (ID: 2181)
# ✅ Created post: 'My Photo Gallery' (ID: 44802)
# 📝 Post URL: https://www.globalnerdy.com/?p=44802
#
# 🎉 Success! Post created with 30 images
# 📝 Edit your post at: https://www.globalnerdy.com/?p=44802

# %%
def closest_sunday():
    """
    Calculate the date of the closest upcoming Sunday.
    If today is Sunday, return today; otherwise, return the next Sunday.
    """
    today = datetime.now()
    if today.weekday() == 6:
        days_until_sunday = 0
    else:
        days_until_sunday = 6 - today.weekday()  # 5 is Saturday, 0 is Monday
        if days_until_sunday < 0 :
            days_until_sunday += 7
    return today + timedelta(days=days_until_sunday)

def title():
    sunday_text = closest_sunday().strftime("%A, %B %-d")
    return f"Sunday picdump for {sunday_text}"


SITE_URL = "https://joeydevilla.com"
load_dotenv()
USERNAME = os.getenv("ACCORDION_GUY_WORDPRESS_USERNAME")
PASSWORD = os.getenv("ACCORDION_GUY_WORDPRESS_APP_PASSWORD")  # Use application password, not regular password
PHOTO_FOLDER = "/Users/joey/Documents/Blog/Accordion Guy/picdump AG/"
POST_TITLE = title()
POST_INTRO = """<p>It’s Sunday, and it’s time for another “picdump!” Here are the memes, pictures, and cartoons floating
around the internet that I found interesting or relevant this week. Share and enjoy!</p>"""
POST_STATUS = "draft"  # Change to "publish" to publish immediately

# Categories and Tags
CATEGORIES = ["Picdump", "Spicy"]  # Will be created if they don't exist
TAGS = []  # Will be created if they don't exist

# Create uploader instance
uploader = WordPressUploader(SITE_URL, USERNAME, PASSWORD)

# Test connection
if not uploader.test_connection():
    print("❌ Cannot connect to WordPress. Check your credentials and site URL.")
    raise SystemExit(1)

# Upload photos and create post
post_info = uploader.create_post_with_images(
    folder_path=PHOTO_FOLDER,
    post_title=POST_TITLE,
    post_intro=POST_INTRO,
    post_status=POST_STATUS,
    categories=CATEGORIES,
    tags=TAGS
)

if post_info:
    print(f"\n🎉 Success! Post created with {len(post_info)} images")
    print(f"📝 Edit your post at: {post_info['link']}")
else:
    print("\n❌ Failed to create post")
# Out:
# ✅ Successfully connected to WordPress!
# 🚀 Starting upload process for folder: /Users/joey/Documents/Blog/Accordion Guy/picdump AG/
# 📁 Found 178 image(s) in folder
# ✅ Uploaded: 4 seasons in florida.JPG (ID: 122528)
# ✅ Uploaded: 400 years ago wasnt great either.jpg (ID: 122529)
# ✅ Uploaded: a felon married to an immigrant.jpg (ID: 122530)
# ✅ Uploaded: aliigator alcatraz merch.JPG (ID: 122531)
# ✅ Uploaded: alligator alcatraz is a modern-day lynching joke.jpg (ID: 122532)
# ✅ Uploaded: alligator alcatraz.jpg (ID: 122533)
# ✅ Uploaded: alligator auschwitz seems more fitting.jpg (ID: 122534)
# ✅ Uploaded: alligator auschwitz.jpg (ID: 122535)
# ✅ Uploaded: amendment to give veterans jobs back.JPG (ID: 122536)
# ✅ Uploaded: america is beautiful contradictory unfinished.jpg (ID: 122537)
# ✅ Uploaded: american who dont want to fight.JPG (ID: 122538)
# ❌ Failed to upload americans seeking healthcare in rural hospita;s 2026-27.jpg: 500 - {"code":"rest_upload_sideload_error","message":"Sorry, you are not allowed to upload this file type.","data":{"status":500}}
# ✅ Uploaded: architect - jurassic sequel.jpg (ID: 122539)
# ✅ Uploaded: arrested for speeding.jpg (ID: 122540)
# ✅ Uploaded: at least billionaires are getting richer.jpg (ID: 122541)
# ✅ Uploaded: baby i am the streets.jpg (ID: 122542)
# ✅ Uploaded: be so completely yourself.jpg (ID: 122543)
# ✅ Uploaded: beyond deplorable.jpeg (ID: 122544)
# ✅ Uploaded: big beautiful buildup.png (ID: 122545)
# ✅ Uploaded: bresnahan selling centene stock.jpg (ID: 122546)
# ✅ Uploaded: bruce lee.jpg (ID: 122547)
# ✅ Uploaded: but they were all of them deceived.JPG (ID: 122548)
# ✅ Uploaded: can build concentration camps but cant help hurricane victims.jpg (ID: 122549)
# ✅ Uploaded: cant find the words.jpg (ID: 122550)
# ✅ Uploaded: cant see when im tagged.jpg (ID: 122551)
# ✅ Uploaded: caricature gone wrong.jpg (ID: 122552)
# ✅ Uploaded: cat playing tuba.jpg (ID: 122553)
# ✅ Uploaded: charlie kirk dropped out of community college.jpg (ID: 122554)
# ✅ Uploaded: charlie kirk is unqualified.jpg (ID: 122555)
# ✅ Uploaded: charlie kirk romanticizing.jpg (ID: 122556)
# ✅ Uploaded: condemned to use the tools of my enemy.jpg (ID: 122557)
# ✅ Uploaded: confounding variables.jpg (ID: 122558)
# ✅ Uploaded: cube globe.jpg (ID: 122559)
# ✅ Uploaded: death to tyrants.JPG (ID: 122560)
# ✅ Uploaded: divided world.jpg (ID: 122561)
# ✅ Uploaded: do not mourn as you leave the beach.jpg (ID: 122562)
# ✅ Uploaded: dudes_who_make_32k_a_year.jpg (ID: 122563)
# ✅ Uploaded: electric vs acoustic cancer.jpg (ID: 122564)
# ✅ Uploaded: every pediatrcian needs a favorite.JPG (ID: 122565)
# ✅ Uploaded: every trait disqualifying ice agent from previous jobs.JPG (ID: 122566)
# ✅ Uploaded: evil is the absence of empathy.jpg (ID: 122567)
# ✅ Uploaded: extrovert friend ordering for me.jpg (ID: 122568)
# ✅ Uploaded: eyes only for her.jpg (ID: 122569)
# ✅ Uploaded: female wolf.jpg (ID: 122570)
# ✅ Uploaded: finewith disappearingpeople now.jpg (ID: 122571)
# ✅ Uploaded: for cutting off trade with all parts of the world.JPG (ID: 122572)
# ✅ Uploaded: ford mavericks stored in cave.jpg (ID: 122573)
# ✅ Uploaded: found these in a burger king bathroom.jpg (ID: 122574)
# ✅ Uploaded: fox is really nailing the point.jpg (ID: 122575)
# ✅ Uploaded: free hot dog for ice agents with id.jpg (ID: 122576)
# ✅ Uploaded: german concentration camp - alligator alcatraz.jpg (ID: 122577)
# ✅ Uploaded: glitter trick.jpg (ID: 122578)
# ✅ Uploaded: grafitti removal guy.jpg (ID: 122579)
# ✅ Uploaded: gunther eagleman flip flops.JPG (ID: 122580)
# ✅ Uploaded: happy 3 year anniversary.jpg (ID: 122581)
# ✅ Uploaded: happy independence day.jpg (ID: 122582)
# ✅ Uploaded: he says to signals president.JPG (ID: 122583)
# ✅ Uploaded: he wants you to have fewer days off.JPG (ID: 122584)
# ✅ Uploaded: hello ice.jpg (ID: 122585)
# ✅ Uploaded: helping mom at checkout.jpg (ID: 122586)
# ✅ Uploaded: how do i stop the voices.jpg (ID: 122587)
# ✅ Uploaded: i am chalanting about a lot of things actually.jpg (ID: 122588)
# ✅ Uploaded: i can physically feel myself pick the wrong dialog option.jpg (ID: 122589)
# ✅ Uploaded: i have deep concerns.png (ID: 122590)
# ✅ Uploaded: icy road.jpg (ID: 122591)
# ✅ Uploaded: id rather be hated for who i help than loved for who i hurt.jpg (ID: 122592)
# ✅ Uploaded: if you ever had a move back in with your parents phase.jpg (ID: 122593)
# ✅ Uploaded: if you fantasize about people being eaten by alligators.jpg (ID: 122594)
# ✅ Uploaded: imagine what they say about immigrants whose names they dont know.jpg (ID: 122595)
# ✅ Uploaded: immigrants and anchor babies.jpg (ID: 122596)
# ✅ Uploaded: improvised protective gear.jpg (ID: 122597)
# ✅ Uploaded: it grows perhaps the greater.jpg (ID: 122598)
# ✅ Uploaded: its a yellow lab.jpg (ID: 122599)
# ✅ Uploaded: its immaterial.jpg (ID: 122600)
# ✅ Uploaded: its like they didnt listen at all.jpg (ID: 122601)
# ✅ Uploaded: japanese internment camp - alligator alcatraz.jpg (ID: 122602)
# ✅ Uploaded: jedi - his wife - daughter - uncle.jpg (ID: 122603)
# ✅ Uploaded: john oliver on big beautiful bill.jpg (ID: 122604)
# ✅ Uploaded: just got fired from walmart.jpg (ID: 122605)
# ✅ Uploaded: kid who fought back once.JPG (ID: 122606)
# ✅ Uploaded: killing me softly with his thing.jpg (ID: 122607)
# ✅ Uploaded: king harold a second army has landed.jpg (ID: 122608)
# ✅ Uploaded: konstantin nikolaev.JPG (ID: 122609)
# ✅ Uploaded: landlords and executives or art and human flourishing.jpg (ID: 122610)
# ✅ Uploaded: lgbtq book ban advocate does the expected.jpg (ID: 122611)
# ✅ Uploaded: living in florida.JPG (ID: 122612)
# ✅ Uploaded: look in the mirror.JPG (ID: 122613)
# ✅ Uploaded: lots of toilet paper.jpg (ID: 122614)
# ✅ Uploaded: mansplaining.jpg (ID: 122615)
# ✅ Uploaded: may your socks always be wet.jpg (ID: 122616)
# ✅ Uploaded: mcconnell wants them to get over it.jpg (ID: 122617)
# ✅ Uploaded: me when someone asks how much i love.JPG (ID: 122618)
# ✅ Uploaded: medicaid cuts will hurt you.jpg (ID: 122619)
# ✅ Uploaded: mens bathroom at kansas city war memorial.JPG (ID: 122620)
# ✅ Uploaded: more costcos in walkable neighborhoods.jpg (ID: 122621)
# ✅ Uploaded: morning wood ranch.jpg (ID: 122622)
# ✅ Uploaded: mount rushmore aghast.jpg (ID: 122623)
# ✅ Uploaded: nebraska.JPG (ID: 122624)
# ✅ Uploaded: not a good look america.JPG (ID: 122625)
# ✅ Uploaded: not a short list.jpg (ID: 122626)
# ✅ Uploaded: not doing homework for a week.jpg (ID: 122627)
# ✅ Uploaded: not inalienable right but conditional privileges.JPG (ID: 122628)
# ✅ Uploaded: not seeing a number.jpg (ID: 122629)
# ✅ Uploaded: nuts and bolts.JPG (ID: 122630)
# ✅ Uploaded: once you build a massive deportation machine.jpg (ID: 122631)
# ✅ Uploaded: one big beautiful bill.jpg (ID: 122632)
# ✅ Uploaded: one second before.JPG (ID: 122633)
# ✅ Uploaded: only 5000 beds in alligator alcatraz.JPG (ID: 122634)
# ✅ Uploaded: palantir.jpg (ID: 122635)
# ✅ Uploaded: palette_swap.jpg (ID: 122636)
# ✅ Uploaded: people dont receive medicaid.jpg (ID: 122637)
# ✅ Uploaded: people in true story movie vs actual photo in end credits.jpg (ID: 122638)
# ✅ Uploaded: people will tell you theyre scared of this.jpg (ID: 122639)
# ✅ Uploaded: peter thiel shows trump how to sort by ethnicity.jpg (ID: 122640)
# ✅ Uploaded: police cart.jpg (ID: 122641)
# ✅ Uploaded: pretended offenses.JPG (ID: 122642)
# ✅ Uploaded: prisoners trolley problemma.jpg (ID: 122643)
# ✅ Uploaded: pro-life indeed.jpg (ID: 122644)
# ✅ Uploaded: purposely marching out of sync.JPG (ID: 122645)
# ✅ Uploaded: rather be woke than morally broke.jpg (ID: 122646)
# ✅ Uploaded: regime change in mongolia.jpg (ID: 122647)
# ✅ Uploaded: republican message is simple.jpg (ID: 122648)
# ✅ Uploaded: revitalized downtown bingo.jpg (ID: 122649)
# ✅ Uploaded: rfk jr when meeting with cdc scientists.jpg (ID: 122650)
# ✅ Uploaded: same picture.JPG (ID: 122651)
# ✅ Uploaded: ship of thesaurus.jpg (ID: 122652)
# ✅ Uploaded: ships waiting to get into panama canal.jpg (ID: 122653)
# ✅ Uploaded: single persons food pyramid.jpg (ID: 122654)
# ✅ Uploaded: someone tucks you in at night.jpg (ID: 122655)
# ✅ Uploaded: someone will suggest executions.jpg (ID: 122656)
# ✅ Uploaded: south korean library on train.jpg (ID: 122657)
# ✅ Uploaded: start calling out his voters.jpg (ID: 122658)
# ✅ Uploaded: super hot dog.jpg (ID: 122659)
# ✅ Uploaded: sure i screwed myself over.jpg (ID: 122660)
# ✅ Uploaded: tell me about yourself.JPG (ID: 122661)
# ✅ Uploaded: terminator_2_themes.png (ID: 122662)
# ✅ Uploaded: tesla robotaxi keeps changing subject to white genocide.JPG (ID: 122663)
# ✅ Uploaded: that has made all the difference.jpg (ID: 122664)
# ✅ Uploaded: that one 4th of july.jpg (ID: 122665)
# ✅ Uploaded: thats just my mom.JPG (ID: 122666)
# ✅ Uploaded: thats not how freedom works.jpg (ID: 122667)
# ✅ Uploaded: thats the liege you swore your vassale to.jpg (ID: 122668)
# ✅ Uploaded: the most propaganzdized people in the world.jpg (ID: 122669)
# ✅ Uploaded: these people have lost their sense of shame.JPG (ID: 122670)
# ✅ Uploaded: they danced to ymca.jpg (ID: 122671)
# ✅ Uploaded: thom tillis.JPG (ID: 122672)
# ✅ Uploaded: towing ice.jpg (ID: 122673)
# ✅ Uploaded: trickle-down economics.jpg (ID: 122674)
# ✅ Uploaded: trump blowing out democracy candle.jpeg (ID: 122675)
# ✅ Uploaded: trump doctrine.JPG (ID: 122676)
# ✅ Uploaded: truth about texas power grid.jpg (ID: 122677)
# ✅ Uploaded: violate flag code.JPG (ID: 122678)
# ✅ Uploaded: vote for me to end wars.JPG (ID: 122679)
# ✅ Uploaded: voted to close nursing homes and more.jpg (ID: 122680)
# ✅ Uploaded: weird accusation but cool story.JPG (ID: 122681)
# ✅ Uploaded: were not all picasso.jpg (ID: 122682)
# ✅ Uploaded: what counts as a once in a generation opportunity.jpg (ID: 122683)
# ✅ Uploaded: what kind of people could work for ice.JPG (ID: 122684)
# ✅ Uploaded: what was so bad about iran deal.JPG (ID: 122685)
# ✅ Uploaded: whats wrong with you people.jpg (ID: 122686)
# ✅ Uploaded: when you grab the taken mug.jpg (ID: 122687)
# ✅ Uploaded: when your loyatly to a felon is greater.jpg (ID: 122688)
# ✅ Uploaded: where did arbys get 2.9 billion.JPG (ID: 122689)
# ✅ Uploaded: why afraid of socialism but not fascism.jpg (ID: 122690)
# ✅ Uploaded: why are they 88 feet.JPG (ID: 122691)
# ✅ Uploaded: why c-3pos memory was wiped but r2d2s wasnt.jpg (ID: 122692)
# ✅ Uploaded: why is it always republicans.JPG (ID: 122693)
# ✅ Uploaded: word of the incident.JPG (ID: 122694)
# ✅ Uploaded: wouldve been fighting for king george.JPG (ID: 122695)
# ✅ Uploaded: wrong trans.JPG (ID: 122696)
# ✅ Uploaded: yall dont call 50 cent curtis.jpg (ID: 122697)
# ✅ Uploaded: yo-yo ma finally works up courage.jpg (ID: 122698)
# ✅ Uploaded: you think gutting medicaid wont ruin you.jpg (ID: 122699)
# ✅ Uploaded: you told him this behavior was presidential and positive.jpg (ID: 122700)
# ✅ Uploaded: you too.JPG (ID: 122701)
# ✅ Uploaded: youjust arent going to have hospitals or schools.jpg (ID: 122702)
# ✅ Uploaded: youre in a cult.JPG (ID: 122703)
# ✅ Uploaded: zohran eating rice with his hands.jpg (ID: 122704)
# ✅ Successfully uploaded 177 out of 178 images
# 📂 Found existing category: Picdump (ID: 1771)
# 📂 Found existing category: Spicy (ID: 1772)
# ✅ Created post: 'Sunday picdump for Sunday, July 06' (ID: 122705)
# 📝 Post URL: https://www.joeydevilla.com/?p=122705
#
# 🎉 Success! Post created with 30 images
# 📝 Edit your post at: https://www.joeydevilla.com/?p=122705
